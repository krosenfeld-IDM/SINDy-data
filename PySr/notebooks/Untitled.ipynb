# %%
import numpy as np
from pysr import PySRRegressor
import matplotlib.pyplot as plt

# %%
X = 2 * np.random.randn(100, 5) # (100, 5 matrix)
y = 2.5382 * np.cos(X[:, 3]) + X[:, 0] ** 2 - 0.5
plt.scatter(X[:,3], X[:,0], c=y)
plt.xlabel('X[:,3]')
plt.ylabel('X[:,0]')
plt.colorbar();

# %%
model = PySRRegressor(
    niterations=40,  # < Increase me for better results
    binary_operators=["+", "*"],
    unary_operators=[
        "cos",
        "exp",
        "sin",
        "inv(x) = 1/x",
        # ^ Custom operator (julia syntax)
    ],
    extra_sympy_mappings={"inv": lambda x: 1 / x},
    # ^ Define operator for SymPy as well
    loss="loss(prediction, target) = (prediction - target)^2",
    # ^ Custom loss function (julia syntax)
)

# %%
model.fit(X, y)
# Out:
# /home/krosenfeld/playpen/SINDy-data/env/lib/python3.8/site-packages/pysr/sr.py:1296: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
